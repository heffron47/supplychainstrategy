# %% [markdown]
# # Supply Chain Strategy FedEx Part 4 Script
# #### Jake Heffron

# %% [markdown]
# This script imports/utilizes the following data: weight and destination data from 22,376 shipments in the FedEx network, the transportation costs at each weight and zone for the three relevant service types (HD, GR, and E2), and the zone/transit data for each origin DC/store location.
#
# The script generates every possible logistics cost for each shipment, selects the lowest one under the following constraints:
# - The number of transit days must be 2 or below
# - The GR service is not chosen if a given shipment is below 70 lbs
#
# Then, the script redistributes some shipments based on the following additional constraints (in this order):
# - Stores with shipment counts below 500 are eliminated and their shipments are reassigned to the next-lowest-cost option
# - Stores with shipment counts above 2000 are identified and shipments are reassigned until the shipment count is 2000 (with the least possible impact on cost)
#
# The script outputs an Excel workbook containing the original 22,376 shipments with their newly generated total logistics cost, origin location, and service type.

# %%
import pandas as pd

# %%
# loading data
ship_hist = pd.read_excel("Python Part 4 Input.xlsx", sheet_name="Clean Shipping History")

zips = ["90808", "17339", "08330", "21702", "28214", "33304", "38138", "54304", "55105", "57106", "58321", "60525", "75141", "78523", "80640", "82201", "84107", "84602", "89502", "92195", "95824", "97060"]
transit_tables = {}

for zip in zips:
    transit_tables[zip] = pd.read_excel("Transit Tables by Zip.xlsx", sheet_name=zip)
    print("loaded transit table " + zip)

# transit_tables["90808"].head()
# Out:
# loaded transit table 90808
# loaded transit table 17339
# loaded transit table 08330
# loaded transit table 21702
# loaded transit table 28214
# loaded transit table 33304
# loaded transit table 38138
# loaded transit table 54304
# loaded transit table 55105
# loaded transit table 57106
# loaded transit table 58321
# loaded transit table 60525
# loaded transit table 75141
# loaded transit table 78523
# loaded transit table 80640
# loaded transit table 82201
# loaded transit table 84107
# loaded transit table 84602
# loaded transit table 89502
# loaded transit table 92195
# loaded transit table 95824
# loaded transit table 97060

# %%
# We don't need all of the columns from the original shipping history file, so we can cut those out
ship_hist = ship_hist[["Destination", "Dest State", "Weight", "Country"]]

# %%
# Loading Rate Tables
services = ["HD", "GR", "E2"]

rate_tables = {}

for i in services:
    table = pd.read_excel("Python Part 4 Input.xlsx", sheet_name="{}".format(i))
    rate_tables[i]=table
    
# Some of the rate tables have inconsistent headers, so here we fix that
rate_tables["GR"] = rate_tables["GR"].rename(columns={"Weight (in Lbs )": "Weight (in Lbs)", "Zone-2": "Zone -02", "Zone-3": "Zone -03", "Zone-4": "Zone -04", "Zone-5": "Zone -05", "Zone-6": "Zone -06", "Zone-7": "Zone -07", "Zone-8": "Zone -08"})
rate_tables["HD"] = rate_tables["HD"].rename(columns={"Weight (in Lbs )": "Weight (in Lbs)"})
    
rate_tables["HD"]
# Out:
#     Weight (in Lbs)  Zone -02  Zone -03  Zone -04  Zone -05  Zone -06  \
# 0                 1      8.64      8.64      8.64      8.72      8.99
# 1                 2      8.64      8.79      9.29      9.43      9.77
# 2                 3      8.64      9.06      9.62      9.84     10.20
# 3                 4      8.64      9.22      9.97     10.30     10.58
# 4                 5      8.80      9.29     10.25     10.60     10.86
# ..              ...       ...       ...       ...       ...       ...
# 65               66     16.22     19.82     21.90     26.92     32.04
# 66               67     16.35     20.00     22.18     26.99     32.27
# 67               68     16.46     20.18     22.46     27.32     32.43
# 68               69     16.58     20.31     22.74     27.66     32.58
# 69               70     16.68     20.46     23.02     27.97     32.91
#
#     Zone -07  Zone -08
# 0       9.07      9.18
# 1       9.86     10.12
# 2      10.37     10.88
# 3      10.87     11.47
# 4      11.21     11.93
# ..       ...       ...
# 65     36.96     42.98
# 66     37.13     43.08
# 67     37.32     43.17
# 68     37.49     43.29
# 69     37.61     43.64
#
# [70 rows x 8 columns]

# %% [markdown]
# Looks good! Now that all of the tables are loaded, we need to pull in the operations cost for each store/DC. While this could be pulled from a workbook, I decided to do it manually.

# %%
# Create Operations Cost Dictionary
ops_costs = [.9,.95,2.5,3.6,2.5,3.3,3.15,3.2,3.4,3.5,3.3,3,2.9,4,3.1,3.8,3.1,3,3.1,3.9,3.3,3.7]
transit_table_ops = {zips[i]: ops_costs[i] for i in range(len(zips))}
print(transit_table_ops)
# Out:
# {'90808': 0.9, '17339': 0.95, '08330': 2.5, '21702': 3.6, '28214': 2.5, '33304': 3.3, '38138': 3.15, '54304': 3.2, '55105': 3.4, '57106': 3.5, '58321': 3.3, '60525': 3, '75141': 2.9, '78523': 4, '80640': 3.1, '82201': 3.8, '84107': 3.1, '84602': 3, '89502': 3.1, '92195': 3.9, '95824': 3.3, '97060': 3.7}

# %% [markdown]
# #### Generating all possible rates

# %% [markdown]
# To generate all possible combined logistics costs for each shipment, we first must pull the relevant zone (and transit time, to be used later) for each of the 22 locations for each shipment. Then, we can look up the cost for the shipments using the zone and the associated weight, then add the operations cost.

# %%
for transit_table in transit_tables:
    # First must get zones from all origin DC's
    ship_hist_zone = ship_hist.merge(transit_tables[transit_table], how="left", left_on="Destination", right_on="Destination Zip")
    ship_hist_zone = ship_hist_zone.rename(columns={"Zone": "zone_from_{}".format(transit_table)})
    ship_hist_zone = ship_hist_zone.rename(columns={"Transit": "transit_from_{}".format(transit_table)})
    
    # Pulling in the transit times and zones from each origin. If this has already ran in the script, it will be passed
    try:
        ship_hist[["zone_from_{}".format(transit_table)]] = ship_hist_zone[["zone_from_{}".format(transit_table)]]
        ship_hist[["transit_from_{}".format(transit_table)]] = ship_hist_zone[["transit_from_{}".format(transit_table)]]
    except:
        pass
    
    # This is the most exhaustive part of the script where COMBINED logistics rates are retrieved from each of the 3 rate tables for every shipment
    for rate_table in rate_tables:
        values = []
        for index, row in ship_hist.iterrows():
            rate = rate_tables[rate_table][rate_tables[rate_table]["Weight (in Lbs)"]==row["Weight"]].filter(["Zone -{:02d}".format(int(row["zone_from_{}".format(transit_table)]))], axis=1)
            rate += transit_table_ops[transit_table] # this adds the operations cost to the rate depending on the origin DC
            try:
                # conditional that makes it so GR will not be chosen if shipment is below 70 lbs
                if row["Weight"] <= 70 and rate_table == "GR":
                    values.append(9999)
                else:
                    values.append(rate.iloc[0,0])
            except IndexError:                             # Prevents the code from breaking when there is no relevant rate available--this happens in the HD table where there are no rates for shipments above 70 lbs
                values.append(9999)
            if index == 10000:
                print("iterated through {} rows for service {} from origin {}".format(index, rate_table, transit_table))
        ship_hist["{}_{}_rate".format(transit_table,rate_table)] = values
        print("done with {} for origin {}".format(rate_table, transit_table))

        
ship_hist.head(20)
# Out:
# iterated through 10000 rows for service HD from origin 90808
# done with HD for origin 90808
# iterated through 10000 rows for service GR from origin 90808
# done with GR for origin 90808
# iterated through 10000 rows for service E2 from origin 90808
# done with E2 for origin 90808
# iterated through 10000 rows for service HD from origin 17339
# done with HD for origin 17339
# iterated through 10000 rows for service GR from origin 17339
# done with GR for origin 17339
# iterated through 10000 rows for service E2 from origin 17339
# done with E2 for origin 17339
# iterated through 10000 rows for service HD from origin 08330
# done with HD for origin 08330
# iterated through 10000 rows for service GR from origin 08330
# done with GR for origin 08330
# iterated through 10000 rows for service E2 from origin 08330
# done with E2 for origin 08330
# iterated through 10000 rows for service HD from origin 21702
# done with HD for origin 21702
# iterated through 10000 rows for service GR from origin 21702
# done with GR for origin 21702
# iterated through 10000 rows for service E2 from origin 21702
# done with E2 for origin 21702
# iterated through 10000 rows for service HD from origin 28214
# done with HD for origin 28214
# iterated through 10000 rows for service GR from origin 28214
# done with GR for origin 28214
# iterated through 10000 rows for service E2 from origin 28214
# done with E2 for origin 28214
# iterated through 10000 rows for service HD from origin 33304
# done with HD for origin 33304
# iterated through 10000 rows for service GR from origin 33304
# done with GR for origin 33304
# iterated through 10000 rows for service E2 from origin 33304
# done with E2 for origin 33304
# iterated through 10000 rows for service HD from origin 38138
# done with HD for origin 38138
# iterated through 10000 rows for service GR from origin 38138
# done with GR for origin 38138
# iterated through 10000 rows for service E2 from origin 38138
# done with E2 for origin 38138
# iterated through 10000 rows for service HD from origin 54304
# done with HD for origin 54304
# iterated through 10000 rows for service GR from origin 54304
# done with GR for origin 54304
# iterated through 10000 rows for service E2 from origin 54304
# done with E2 for origin 54304
# iterated through 10000 rows for service HD from origin 55105
# done with HD for origin 55105
# iterated through 10000 rows for service GR from origin 55105
# done with GR for origin 55105
# iterated through 10000 rows for service E2 from origin 55105
# done with E2 for origin 55105
# iterated through 10000 rows for service HD from origin 57106
# done with HD for origin 57106
# iterated through 10000 rows for service GR from origin 57106
# done with GR for origin 57106
# iterated through 10000 rows for service E2 from origin 57106
# done with E2 for origin 57106
# iterated through 10000 rows for service HD from origin 58321
# done with HD for origin 58321
# iterated through 10000 rows for service GR from origin 58321
# done with GR for origin 58321
# iterated through 10000 rows for service E2 from origin 58321
# done with E2 for origin 58321
# iterated through 10000 rows for service HD from origin 60525
# done with HD for origin 60525
# iterated through 10000 rows for service GR from origin 60525
# done with GR for origin 60525
# iterated through 10000 rows for service E2 from origin 60525
# done with E2 for origin 60525
# iterated through 10000 rows for service HD from origin 75141
# done with HD for origin 75141
# iterated through 10000 rows for service GR from origin 75141
# done with GR for origin 75141
# iterated through 10000 rows for service E2 from origin 75141
# done with E2 for origin 75141
# iterated through 10000 rows for service HD from origin 78523
# done with HD for origin 78523
# iterated through 10000 rows for service GR from origin 78523
# done with GR for origin 78523
# iterated through 10000 rows for service E2 from origin 78523
# done with E2 for origin 78523
# iterated through 10000 rows for service HD from origin 80640
# done with HD for origin 80640
# iterated through 10000 rows for service GR from origin 80640
# done with GR for origin 80640
# iterated through 10000 rows for service E2 from origin 80640
# done with E2 for origin 80640
# iterated through 10000 rows for service HD from origin 82201
# done with HD for origin 82201
# iterated through 10000 rows for service GR from origin 82201
# done with GR for origin 82201
# iterated through 10000 rows for service E2 from origin 82201
# done with E2 for origin 82201
# iterated through 10000 rows for service HD from origin 84107
# done with HD for origin 84107
# iterated through 10000 rows for service GR from origin 84107
# done with GR for origin 84107
# iterated through 10000 rows for service E2 from origin 84107
# done with E2 for origin 84107
# iterated through 10000 rows for service HD from origin 84602
# done with HD for origin 84602
# iterated through 10000 rows for service GR from origin 84602
# done with GR for origin 84602
# iterated through 10000 rows for service E2 from origin 84602
# done with E2 for origin 84602
# iterated through 10000 rows for service HD from origin 89502
# done with HD for origin 89502
# iterated through 10000 rows for service GR from origin 89502
# done with GR for origin 89502
# iterated through 10000 rows for service E2 from origin 89502
# done with E2 for origin 89502
# iterated through 10000 rows for service HD from origin 92195
# done with HD for origin 92195
# iterated through 10000 rows for service GR from origin 92195
# done with GR for origin 92195
# iterated through 10000 rows for service E2 from origin 92195
# done with E2 for origin 92195
# iterated through 10000 rows for service HD from origin 95824
# done with HD for origin 95824
# iterated through 10000 rows for service GR from origin 95824
# done with GR for origin 95824
# iterated through 10000 rows for service E2 from origin 95824
# done with E2 for origin 95824
# iterated through 10000 rows for service HD from origin 97060
# done with HD for origin 97060
# iterated through 10000 rows for service GR from origin 97060
# done with GR for origin 97060
# iterated through 10000 rows for service E2 from origin 97060
# done with E2 for origin 97060
#     Destination Dest State  Weight Country  zone_from_90808  \
# 0          1001         MA       7      US                8
# 1          1002         MA      11      US                8
# 2          1007         MA       6      US                8
# 3          1012         MA       2      US                8
# 4          1020         MA       5      US                8
# 5          1027         MA       6      US                8
# 6          1028         MA      13      US                8
# 7          1030         MA       8      US                8
# 8          1033         MA       2      US                8
# 9          1036         MA       5      US                8
# 10         1038         MA       6      US                8
# 11         1040         MA       6      US                8
# 12         1056         MA       3      US                8
# 13         1057         MA       6      US                8
# 14         1062         MA       4      US                8
# 15         1069         MA      11      US                8
# 16         1075         MA       2      US                8
# 17         1451         MA       4      US                8
# 18         1453         MA      13      US                8
# 19         1460         MA      20      US                8
#
#     transit_from_90808  90808_HD_rate  90808_GR_rate  90808_E2_rate  \
# 0                    5          13.14         9999.0          29.60
# 1                    5          14.62         9999.0          41.52
# 2                    5          12.88         9999.0          27.00
# 3                    5          11.02         9999.0          16.92
# 4                    5          12.83         9999.0          24.69
# 5                    5          12.88         9999.0          27.00
# 6                    5          16.10         9999.0          46.82
# 7                    5          13.60         9999.0          32.49
# 8                    5          11.02         9999.0          16.92
# 9                    5          12.83         9999.0          24.69
# 10                   5          12.88         9999.0          27.00
# 11                   5          12.88         9999.0          27.00
# 12                   5          11.78         9999.0          19.29
# 13                   5          12.88         9999.0          27.00
# 14                   5          12.37         9999.0          21.83
# 15                   5          14.62         9999.0          41.52
# 16                   5          11.02         9999.0          16.92
# 17                   5          12.37         9999.0          21.83
# 18                   5          16.10         9999.0          46.82
# 19                   5          21.04         9999.0          63.01
#
#     zone_from_17339  ...  zone_from_95824  transit_from_95824  95824_HD_rate  \
# 0                 3  ...                8                   5          15.54
# 1                 3  ...                8                   5          17.02
# 2                 3  ...                8                   5          15.28
# 3                 3  ...                8                   5          13.42
# 4                 3  ...                8                   5          15.23
# 5                 3  ...                8                   5          15.28
# 6                 3  ...                8                   5          18.50
# 7                 3  ...                8                   5          16.00
# 8                 3  ...                8                   5          13.42
# 9                 3  ...                8                   5          15.23
# 10                3  ...                8                   5          15.28
# 11                3  ...                8                   5          15.28
# 12                3  ...                8                   5          14.18
# 13                3  ...                8                   5          15.28
# 14                3  ...                8                   5          14.77
# 15                3  ...                8                   5          17.02
# 16                3  ...                8                   5          13.42
# 17                4  ...                8                   5          14.77
# 18                4  ...                8                   5          18.50
# 19                4  ...                8                   5          23.44
#
#     95824_GR_rate  95824_E2_rate  zone_from_97060  transit_from_97060  \
# 0          9999.0          32.00                8                   5
# 1          9999.0          43.92                8                   5
# 2          9999.0          29.40                8                   5
# 3          9999.0          19.32                8                   5
# 4          9999.0          27.09                8                   5
# 5          9999.0          29.40                8                   5
# 6          9999.0          49.22                8                   5
# 7          9999.0          34.89                8                   5
# 8          9999.0          19.32                8                   5
# 9          9999.0          27.09                8                   5
# 10         9999.0          29.40                8                   5
# 11         9999.0          29.40                8                   5
# 12         9999.0          21.69                8                   5
# 13         9999.0          29.40                8                   5
# 14         9999.0          24.23                8                   5
# 15         9999.0          43.92                8                   5
# 16         9999.0          19.32                8                   5
# 17         9999.0          24.23                8                   5
# 18         9999.0          49.22                8                   5
# 19         9999.0          65.41                8                   5
#
#     97060_HD_rate  97060_GR_rate  97060_E2_rate
# 0           15.94         9999.0          32.40
# 1           17.42         9999.0          44.32
# 2           15.68         9999.0          29.80
# 3           13.82         9999.0          19.72
# 4           15.63         9999.0          27.49
# 5           15.68         9999.0          29.80
# 6           18.90         9999.0          49.62
# 7           16.40         9999.0          35.29
# 8           13.82         9999.0          19.72
# 9           15.63         9999.0          27.49
# 10          15.68         9999.0          29.80
# 11          15.68         9999.0          29.80
# 12          14.58         9999.0          22.09
# 13          15.68         9999.0          29.80
# 14          15.17         9999.0          24.63
# 15          17.42         9999.0          44.32
# 16          13.82         9999.0          19.72
# 17          15.17         9999.0          24.63
# 18          18.90         9999.0          49.62
# 19          23.84         9999.0          65.81
#
# [20 rows x 114 columns]

# %% [markdown]
# Now, we remove rates from consideration that would make a shipment take more than 2 days. Since the lowest cost will ultimately be chosen, we set the GR and HD rates to a very high number ($9,999) if their transit time is above two days. This way, they will not be later chosen as the best option.

# %%
for origin in transit_tables:
    for index, row in ship_hist.iterrows():
        if row["transit_from_{}".format(origin)] > 2:
            ship_hist.at[index, "{}_GR_rate".format(origin)] = 9999
            ship_hist.at[index, "{}_HD_rate".format(origin)] = 9999

ship_hist.head(10)
# Out:
#    Destination Dest State  Weight Country  zone_from_90808  \
# 0         1001         MA       7      US                8
# 1         1002         MA      11      US                8
# 2         1007         MA       6      US                8
# 3         1012         MA       2      US                8
# 4         1020         MA       5      US                8
# 5         1027         MA       6      US                8
# 6         1028         MA      13      US                8
# 7         1030         MA       8      US                8
# 8         1033         MA       2      US                8
# 9         1036         MA       5      US                8
#
#    transit_from_90808  90808_HD_rate  90808_GR_rate  90808_E2_rate  \
# 0                   5         9999.0         9999.0          29.60
# 1                   5         9999.0         9999.0          41.52
# 2                   5         9999.0         9999.0          27.00
# 3                   5         9999.0         9999.0          16.92
# 4                   5         9999.0         9999.0          24.69
# 5                   5         9999.0         9999.0          27.00
# 6                   5         9999.0         9999.0          46.82
# 7                   5         9999.0         9999.0          32.49
# 8                   5         9999.0         9999.0          16.92
# 9                   5         9999.0         9999.0          24.69
#
#    zone_from_17339  ...  zone_from_95824  transit_from_95824  95824_HD_rate  \
# 0                3  ...                8                   5         9999.0
# 1                3  ...                8                   5         9999.0
# 2                3  ...                8                   5         9999.0
# 3                3  ...                8                   5         9999.0
# 4                3  ...                8                   5         9999.0
# 5                3  ...                8                   5         9999.0
# 6                3  ...                8                   5         9999.0
# 7                3  ...                8                   5         9999.0
# 8                3  ...                8                   5         9999.0
# 9                3  ...                8                   5         9999.0
#
#    95824_GR_rate  95824_E2_rate  zone_from_97060  transit_from_97060  \
# 0         9999.0          32.00                8                   5
# 1         9999.0          43.92                8                   5
# 2         9999.0          29.40                8                   5
# 3         9999.0          19.32                8                   5
# 4         9999.0          27.09                8                   5
# 5         9999.0          29.40                8                   5
# 6         9999.0          49.22                8                   5
# 7         9999.0          34.89                8                   5
# 8         9999.0          19.32                8                   5
# 9         9999.0          27.09                8                   5
#
#    97060_HD_rate  97060_GR_rate  97060_E2_rate
# 0         9999.0         9999.0          32.40
# 1         9999.0         9999.0          44.32
# 2         9999.0         9999.0          29.80
# 3         9999.0         9999.0          19.72
# 4         9999.0         9999.0          27.49
# 5         9999.0         9999.0          29.80
# 6         9999.0         9999.0          49.62
# 7         9999.0         9999.0          35.29
# 8         9999.0         9999.0          19.72
# 9         9999.0         9999.0          27.49
#
# [10 rows x 114 columns]

# %%
columns = []
for col in ship_hist.columns:
    if col[-4:] == "rate":
        columns.append(col)
# print(columns)

# New DataFrame that only contains the possible rates for each shipment

ship_hist_rates = ship_hist.filter(columns)

# %% [markdown]
# #### Identifying lowest rate and adjusting to constraints

# %% [markdown]
# First, we will choose the lowest rate for each shipment and record the associated store/DC and service. Then, the script evaluates the shipment count at each store, increases the minimum shipment count to keep the store in consideration (called the "limit") by 1. Once the minimum surpasses the current shipment count at a store, that store is removed and the shipments are reassigned to the next-cheapest option via a recalculation of the best rate for every shipment. This process repeats until the minimum store count reaches 500.  While this part of the script is exhaustive, is the only way to ensure each shipment is reassigned to its most cost-effective origin location.

# %%
# Determine which rate is the lowest and identify the associated service type and origin

def get_best_rates():
    ship_hist_best = pd.DataFrame({"best_rate": ship_hist_rates.min(axis=1)})
#     print(ship_hist_best.shape)
#     print(ship_hist_rates.shape)

    pairs = []
    for index, row in ship_hist_rates.iterrows():
        for col in ship_hist_rates.columns:
            if row[col] == ship_hist_best.iloc[index,0]:
                pairs.append(col)
                break

#     print(len(pairs))

    ship_hist_best["origin_service_pair"] = pairs
    
    # Creating columns for the new origins and services
    location = ship_hist_best["origin_service_pair"].str.slice(0,5)
    service = ship_hist_best["origin_service_pair"].str.slice(6,8)
    # print(location)
    ship_hist_best["new_origin_location"] = location
    ship_hist_best["new_service_type"] = service
    return ship_hist_best

ship_hist_best = get_best_rates()

# Now stores will be eliminated that have under a certain limit of shipments, with that limit being increased up to the 500-shipment constraint

limit = 1
while limit <= 500:
    for col in ship_hist_rates.columns:
        if len(ship_hist_best["new_origin_location"][ship_hist_best["new_origin_location"]==col[0:5]]) < limit:
            ship_hist_rates.drop(columns=col, inplace=True)
            print("dropped column {}".format(col))
#         else:
#             print("didnt drop column {}".format(col))
            ship_hist_best = get_best_rates()
    print("completed limit {}".format(limit))
    limit += 1
    
# ship_hist_rates.sample(10)
# ship_hist_best.sample(10)
# Out:
# dropped column 21702_HD_rate
# dropped column 21702_GR_rate
# dropped column 21702_E2_rate
# dropped column 84107_HD_rate
# dropped column 84107_GR_rate
# dropped column 84107_E2_rate
# dropped column 92195_HD_rate
# dropped column 92195_GR_rate
# dropped column 92195_E2_rate
# completed limit 1
# completed limit 2
# completed limit 3
# completed limit 4
# completed limit 5
# dropped column 95824_HD_rate
# dropped column 95824_GR_rate
# dropped column 95824_E2_rate
# completed limit 6
# completed limit 7
# completed limit 8
# completed limit 9
# completed limit 10
# completed limit 11
# completed limit 12
# completed limit 13
# completed limit 14
# completed limit 15
# completed limit 16
# completed limit 17
# completed limit 18
# completed limit 19
# dropped column 80640_HD_rate
# dropped column 80640_GR_rate
# dropped column 80640_E2_rate
# completed limit 20
# completed limit 21
# completed limit 22
# completed limit 23
# completed limit 24
# completed limit 25
# completed limit 26
# completed limit 27
# dropped column 78523_HD_rate
# dropped column 78523_GR_rate
# dropped column 78523_E2_rate
# completed limit 28
# completed limit 29
# completed limit 30
# completed limit 31
# completed limit 32
# completed limit 33
# completed limit 34
# completed limit 35
# completed limit 36
# completed limit 37
# completed limit 38
# completed limit 39
# completed limit 40
# completed limit 41
# completed limit 42
# completed limit 43
# completed limit 44
# completed limit 45
# completed limit 46
# completed limit 47
# completed limit 48
# completed limit 49
# completed limit 50
# completed limit 51
# completed limit 52
# completed limit 53
# completed limit 54
# completed limit 55
# completed limit 56
# completed limit 57
# completed limit 58
# completed limit 59
# completed limit 60
# completed limit 61
# completed limit 62
# completed limit 63
# completed limit 64
# completed limit 65
# completed limit 66
# completed limit 67
# completed limit 68
# completed limit 69
# completed limit 70
# completed limit 71
# completed limit 72
# completed limit 73
# completed limit 74
# completed limit 75
# completed limit 76
# completed limit 77
# completed limit 78
# completed limit 79
# completed limit 80
# completed limit 81
# completed limit 82
# completed limit 83
# completed limit 84
# completed limit 85
# completed limit 86
# completed limit 87
# dropped column 82201_HD_rate
# dropped column 82201_GR_rate
# dropped column 82201_E2_rate
# completed limit 88
# completed limit 89
# completed limit 90
# completed limit 91
# completed limit 92
# completed limit 93
# completed limit 94
# completed limit 95
# completed limit 96
# completed limit 97
# completed limit 98
# completed limit 99
# completed limit 100
# completed limit 101
# completed limit 102
# completed limit 103
# completed limit 104
# completed limit 105
# completed limit 106
# dropped column 08330_HD_rate
# dropped column 08330_GR_rate
# dropped column 08330_E2_rate
# completed limit 107
# completed limit 108
# completed limit 109
# completed limit 110
# completed limit 111
# completed limit 112
# completed limit 113
# completed limit 114
# completed limit 115
# completed limit 116
# completed limit 117
# completed limit 118
# completed limit 119
# completed limit 120
# completed limit 121
# completed limit 122
# completed limit 123
# completed limit 124
# completed limit 125
# completed limit 126
# completed limit 127
# completed limit 128
# completed limit 129
# dropped column 89502_HD_rate
# dropped column 89502_GR_rate
# dropped column 89502_E2_rate
# completed limit 130
# completed limit 131
# completed limit 132
# completed limit 133
# completed limit 134
# completed limit 135
# completed limit 136
# completed limit 137
# completed limit 138
# completed limit 139
# completed limit 140
# completed limit 141
# completed limit 142
# completed limit 143
# completed limit 144
# completed limit 145
# completed limit 146
# completed limit 147
# completed limit 148
# completed limit 149
# completed limit 150
# completed limit 151
# completed limit 152
# completed limit 153
# completed limit 154
# completed limit 155
# completed limit 156
# completed limit 157
# completed limit 158
# completed limit 159
# completed limit 160
# completed limit 161
# completed limit 162
# completed limit 163
# completed limit 164
# completed limit 165
# dropped column 54304_HD_rate
# dropped column 54304_GR_rate
# dropped column 54304_E2_rate
# completed limit 166
# completed limit 167
# completed limit 168
# completed limit 169
# completed limit 170
# completed limit 171
# completed limit 172
# completed limit 173
# completed limit 174
# completed limit 175
# completed limit 176
# completed limit 177
# completed limit 178
# completed limit 179
# completed limit 180
# completed limit 181
# completed limit 182
# completed limit 183
# completed limit 184
# completed limit 185
# completed limit 186
# completed limit 187
# dropped column 38138_HD_rate
# dropped column 38138_GR_rate
# dropped column 38138_E2_rate
# completed limit 188
# completed limit 189
# completed limit 190
# completed limit 191
# completed limit 192
# completed limit 193
# completed limit 194
# completed limit 195
# completed limit 196
# completed limit 197
# completed limit 198
# completed limit 199
# completed limit 200
# completed limit 201
# completed limit 202
# completed limit 203
# completed limit 204
# completed limit 205
# completed limit 206
# completed limit 207
# completed limit 208
# completed limit 209
# completed limit 210
# completed limit 211
# completed limit 212
# completed limit 213
# completed limit 214
# completed limit 215
# completed limit 216
# completed limit 217
# completed limit 218
# completed limit 219
# completed limit 220
# completed limit 221
# completed limit 222
# completed limit 223
# completed limit 224
# completed limit 225
# completed limit 226
# completed limit 227
# completed limit 228
# completed limit 229
# completed limit 230
# completed limit 231
# dropped column 58321_HD_rate
# dropped column 58321_GR_rate
# dropped column 58321_E2_rate
# completed limit 232
# completed limit 233
# dropped column 33304_HD_rate
# dropped column 33304_GR_rate
# dropped column 33304_E2_rate
# completed limit 234
# completed limit 235
# completed limit 236
# completed limit 237
# completed limit 238
# completed limit 239
# completed limit 240
# completed limit 241
# completed limit 242
# completed limit 243
# completed limit 244
# completed limit 245
# completed limit 246
# completed limit 247
# completed limit 248
# completed limit 249
# completed limit 250
# completed limit 251
# completed limit 252
# completed limit 253
# completed limit 254
# completed limit 255
# completed limit 256
# completed limit 257
# completed limit 258
# completed limit 259
# completed limit 260
# completed limit 261
# completed limit 262
# completed limit 263
# completed limit 264
# completed limit 265
# completed limit 266
# completed limit 267
# completed limit 268
# completed limit 269
# completed limit 270
# completed limit 271
# completed limit 272
# completed limit 273
# completed limit 274
# completed limit 275
# completed limit 276
# completed limit 277
# completed limit 278
# completed limit 279
# completed limit 280
# completed limit 281
# completed limit 282
# completed limit 283
# completed limit 284
# completed limit 285
# completed limit 286
# completed limit 287
# completed limit 288
# completed limit 289
# completed limit 290
# completed limit 291
# completed limit 292
# completed limit 293
# completed limit 294
# completed limit 295
# completed limit 296
# completed limit 297
# completed limit 298
# completed limit 299
# completed limit 300
# completed limit 301
# completed limit 302
# completed limit 303
# completed limit 304
# completed limit 305
# completed limit 306
# completed limit 307
# completed limit 308
# completed limit 309
# completed limit 310
# completed limit 311
# completed limit 312
# completed limit 313
# completed limit 314
# completed limit 315
# completed limit 316
# completed limit 317
# completed limit 318
# completed limit 319
# completed limit 320
# completed limit 321
# completed limit 322
# completed limit 323
# completed limit 324
# completed limit 325
# completed limit 326
# completed limit 327
# completed limit 328
# dropped column 57106_HD_rate
# dropped column 57106_GR_rate
# dropped column 57106_E2_rate
# completed limit 329
# completed limit 330
# completed limit 331
# completed limit 332
# completed limit 333
# completed limit 334
# completed limit 335
# completed limit 336
# completed limit 337
# completed limit 338
# completed limit 339
# completed limit 340
# completed limit 341
# completed limit 342
# completed limit 343
# completed limit 344
# completed limit 345
# completed limit 346
# completed limit 347
# completed limit 348
# completed limit 349
# completed limit 350
# completed limit 351
# completed limit 352
# completed limit 353
# completed limit 354
# completed limit 355
# completed limit 356
# completed limit 357
# completed limit 358
# completed limit 359
# completed limit 360
# completed limit 361
# completed limit 362
# completed limit 363
# completed limit 364
# completed limit 365
# completed limit 366
# completed limit 367
# completed limit 368
# completed limit 369
# completed limit 370
# completed limit 371
# completed limit 372
# completed limit 373
# completed limit 374
# completed limit 375
# completed limit 376
# completed limit 377
# completed limit 378
# completed limit 379
# completed limit 380
# completed limit 381
# completed limit 382
# completed limit 383
# completed limit 384
# completed limit 385
# completed limit 386
# completed limit 387
# completed limit 388
# completed limit 389
# completed limit 390
# completed limit 391
# completed limit 392
# completed limit 393
# completed limit 394
# completed limit 395
# completed limit 396
# completed limit 397
# completed limit 398
# completed limit 399
# completed limit 400
# completed limit 401
# completed limit 402
# completed limit 403
# completed limit 404
# completed limit 405
# completed limit 406
# completed limit 407
# completed limit 408
# completed limit 409
# completed limit 410
# completed limit 411
# completed limit 412
# completed limit 413
# completed limit 414
# completed limit 415
# completed limit 416
# completed limit 417
# completed limit 418
# completed limit 419
# completed limit 420
# completed limit 421
# completed limit 422
# completed limit 423
# completed limit 424
# completed limit 425
# completed limit 426
# completed limit 427
# completed limit 428
# completed limit 429
# completed limit 430
# completed limit 431
# completed limit 432
# completed limit 433
# completed limit 434
# completed limit 435
# completed limit 436
# completed limit 437
# completed limit 438
# completed limit 439
# completed limit 440
# completed limit 441
# completed limit 442
# completed limit 443
# completed limit 444
# completed limit 445
# completed limit 446
# completed limit 447
# completed limit 448
# completed limit 449
# completed limit 450
# completed limit 451
# completed limit 452
# completed limit 453
# completed limit 454
# completed limit 455
# completed limit 456
# completed limit 457
# completed limit 458
# completed limit 459
# completed limit 460
# completed limit 461
# completed limit 462
# completed limit 463
# completed limit 464
# completed limit 465
# completed limit 466
# completed limit 467
# completed limit 468
# completed limit 469
# completed limit 470
# completed limit 471
# completed limit 472
# completed limit 473
# completed limit 474
# completed limit 475
# completed limit 476
# completed limit 477
# completed limit 478
# completed limit 479
# completed limit 480
# completed limit 481
# completed limit 482
# completed limit 483
# completed limit 484
# completed limit 485
# completed limit 486
# completed limit 487
# completed limit 488
# completed limit 489
# completed limit 490
# completed limit 491
# completed limit 492
# completed limit 493
# completed limit 494
# completed limit 495
# completed limit 496
# completed limit 497
# completed limit 498
# completed limit 499
# completed limit 500

# %%
# ship_hist_rates.sample(10)
ship_hist_rates.columns
# Out:
# Index(['90808_HD_rate', '90808_GR_rate', '90808_E2_rate', '17339_HD_rate',
#        '17339_GR_rate', '17339_E2_rate', '28214_HD_rate', '28214_GR_rate',
#        '28214_E2_rate', '55105_HD_rate', '55105_GR_rate', '55105_E2_rate',
#        '60525_HD_rate', '60525_GR_rate', '60525_E2_rate', '75141_HD_rate',
#        '75141_GR_rate', '75141_E2_rate', '84602_HD_rate', '84602_GR_rate',
#        '84602_E2_rate', '97060_HD_rate', '97060_GR_rate', '97060_E2_rate'],
#       dtype='object')

# %% [markdown]
# At this point in the script, there is one store--zip code 75141--with 2096 shipments despite the provided constraint of 2000 shipments to a given store. Luckily, the script can automatically identify which 96 shipments would be least impacted (cost-wise) by reassignment!
#
# First, for all shipments, we identify what the best option would be if store 75141 were to be completely removed from consideration.

# %%
# Now we deal with 75141 where there are 2096 shipments (maximum for stores is 2000)
# First we identify the next best option for 75141 shipments
ship_hist_rates_no_75141 = ship_hist_rates.drop(columns=["75141_HD_rate", "75141_GR_rate", "75141_E2_rate"])


ship_hist_best_no_75141 = pd.DataFrame({"no_75141_best_rate": ship_hist_rates_no_75141.min(axis=1)})
#     print(ship_hist_best.shape)
#     print(ship_hist_rates.shape)

pairs_no_75141 = []
for index, row in ship_hist_rates_no_75141.iterrows():
    for col in ship_hist_rates_no_75141.columns:
        if row[col] == ship_hist_best_no_75141.iloc[index,0]:
            pairs_no_75141.append(col)
#             row["second_best_rate"] = row.drop(columns=col).min()
            break

#     print(len(pairs))

ship_hist_best_no_75141["no_75141_origin_service_pair"] = pairs_no_75141
#     print(origin_service_pair)

# Creating columns for the new origins and services
location = ship_hist_best_no_75141["no_75141_origin_service_pair"].str.slice(0,5)
service = ship_hist_best_no_75141["no_75141_origin_service_pair"].str.slice(6,8)
# print(location)
ship_hist_best_no_75141["no_75141_new_origin_location"] = location
ship_hist_best_no_75141["no_75141_new_service_type"] = service

if "no_75141_best_rate" not in ship_hist_best:
    ship_hist_best = pd.concat([ship_hist_best,ship_hist_best_no_75141], axis=1)

ship_hist_best[ship_hist_best["new_origin_location"]=="75141"].sample(10)
# Out:
#        best_rate origin_service_pair new_origin_location new_service_type  \
# 15923      11.69       75141_HD_rate               75141               HD
# 16593      15.59       75141_HD_rate               75141               HD
# 16793      11.69       75141_HD_rate               75141               HD
# 15961      17.50       75141_HD_rate               75141               HD
# 21248      13.70       75141_HD_rate               75141               HD
# 16310      11.45       75141_E2_rate               75141               E2
# 10068      14.21       75141_HD_rate               75141               HD
# 10055      38.54       75141_GR_rate               75141               GR
# 9797       13.70       75141_HD_rate               75141               HD
# 16189      11.70       75141_HD_rate               75141               HD
#
#        no_75141_best_rate no_75141_origin_service_pair  \
# 15923               12.16                84602_E2_rate
# 16593               18.39                60525_HD_rate
# 16793               12.43                84602_HD_rate
# 15961               23.15                84602_HD_rate
# 21248               13.80                60525_HD_rate
# 16310               12.43                60525_HD_rate
# 10068               14.65                60525_HD_rate
# 10055               40.58                60525_GR_rate
# 9797                13.84                28214_HD_rate
# 16189               13.60                60525_HD_rate
#
#       no_75141_new_origin_location no_75141_new_service_type
# 15923                        84602                        E2
# 16593                        60525                        HD
# 16793                        84602                        HD
# 15961                        84602                        HD
# 21248                        60525                        HD
# 16310                        60525                        HD
# 10068                        60525                        HD
# 10055                        60525                        GR
# 9797                         28214                        HD
# 16189                        60525                        HD

# %% [markdown]
# Now, we identify the 96 shipments with the most negligible difference in cost between 75141 and the next best option--these will be the rerouted shipments.

# %%
ship_hist_best["75141_alt_diff"] = ship_hist_best["no_75141_best_rate"] - ship_hist_best["best_rate"]

# list(ship_hist_best["75141_alt_diff"])
differences = pd.DataFrame({"difference": list(ship_hist_best["75141_alt_diff"]), "index": ship_hist_best.index})
differences = differences.sort_values(by="difference")
# print(differences)


differences_filtered = differences[differences["difference"]>0]

differences_filtered = differences_filtered[0:96]
display(differences_filtered)
# Out:
#        difference  index
# 19680        0.02  19680
# 19682        0.02  19682
# 10015        0.02  10015
# 9907         0.02   9907
# 16131        0.02  16131
# ...           ...    ...
# 17813        0.04  17813
# 9690         0.05   9690
# 9660         0.05   9660
# 15748        0.05  15748
# 21313        0.05  21313
#
# [96 rows x 2 columns]

# %% [markdown]
# It looks like the 96 shipments have a very small (between 2 and 5 cent) difference between using 75141 and the next best option. Awesome! Now, for those 96 shipments, we reassign to the next best option.

# %%
# Finally, we reassign the appropriate 96 indexes to their secondary location!
for index, row in ship_hist_best.iterrows():
    if index in list(differences_filtered["index"]):
        ship_hist_best.at[index, "best_rate"] = row["no_75141_best_rate"]
        ship_hist_best.at[index, "origin_service_pair"] = row["no_75141_origin_service_pair"]
        ship_hist_best.at[index, "new_origin_location"] = row["no_75141_new_origin_location"]
        ship_hist_best.at[index, "new_service_type"] = row["no_75141_new_service_type"]
        print("replaced index {}".format(index))

# Dropping columns we don't need in the output
ship_hist_best.drop(columns=["no_75141_best_rate", "no_75141_origin_service_pair", "no_75141_new_origin_location", "no_75141_new_service_type", "75141_alt_diff"], inplace=True)
# Out:
# replaced index 7509
# replaced index 8457
# replaced index 9352
# replaced index 9353
# replaced index 9369
# replaced index 9444
# replaced index 9467
# replaced index 9561
# replaced index 9565
# replaced index 9573
# replaced index 9590
# replaced index 9645
# replaced index 9660
# replaced index 9664
# replaced index 9690
# replaced index 9739
# replaced index 9740
# replaced index 9746
# replaced index 9824
# replaced index 9907
# replaced index 9909
# replaced index 9911
# replaced index 9912
# replaced index 9928
# replaced index 9990
# replaced index 9992
# replaced index 9999
# replaced index 10000
# replaced index 10001
# replaced index 10007
# replaced index 10008
# replaced index 10009
# replaced index 10010
# replaced index 10015
# replaced index 10016
# replaced index 10642
# replaced index 10650
# replaced index 10655
# replaced index 10659
# replaced index 15683
# replaced index 15700
# replaced index 15724
# replaced index 15726
# replaced index 15743
# replaced index 15744
# replaced index 15748
# replaced index 16129
# replaced index 16131
# replaced index 17037
# replaced index 17802
# replaced index 17813
# replaced index 17822
# replaced index 17826
# replaced index 19422
# replaced index 19441
# replaced index 19457
# replaced index 19460
# replaced index 19678
# replaced index 19680
# replaced index 19682
# replaced index 19683
# replaced index 19699
# replaced index 20385
# replaced index 21185
# replaced index 21192
# replaced index 21200
# replaced index 21201
# replaced index 21206
# replaced index 21209
# replaced index 21216
# replaced index 21221
# replaced index 21225
# replaced index 21226
# replaced index 21227
# replaced index 21236
# replaced index 21259
# replaced index 21274
# replaced index 21282
# replaced index 21289
# replaced index 21313
# replaced index 21321
# replaced index 21326
# replaced index 21337
# replaced index 21345
# replaced index 21814
# replaced index 21815
# replaced index 21820
# replaced index 21821
# replaced index 21827
# replaced index 21840
# replaced index 21856
# replaced index 21868
# replaced index 21878
# replaced index 21879
# replaced index 21884
# replaced index 21904

# %% [markdown]
# We can quickly calculate the transit days for each shipment with the new origin locations (rather than writing 22 "IF" statements in Excel).

# %%
# for index, row in ship_hist.iterrows():
#     for best_index, best_row in ship_hist_best.iterrows():
#         if best_row["new_service_type"] == "E2":
#             ship_hist_best.at[best_index, "transit_time"] = 2
#         else:
#             table = transit_tables[best_row["new_origin_location"]]
#             table.head()
#             ship_hist_best.at[best_index, "transit_time"] = table[table["Destination Zip"]==row["Destination"]]["Transit"]

for index, row in ship_hist_best.iterrows():
        if row["new_service_type"] == "E2":
            ship_hist_best.at[index, "transit_time"] = 2
        else:
            ship_hist_best.at[index,"transit_time"] = ship_hist.loc[index,"transit_from_{}".format(row["new_origin_location"])]

# %% [markdown]
# #### Output
# Now we're done! Let's write our results to an Excel table and go get a glass of water.

# %%
# Write new data to Excel
ship_hist_best.to_excel("Python Part 4 Output.xlsx", sheet_name="Optimized Shipments")

# %%
# Original shipping history file with every possible rate for each shipment. Not necessary for deliverable but can help explain script
ship_hist.to_excel("Python 4 Shipments Output.xlsx")
